# %%
details = {'Name': 'Vinay', 
           'Age':25, 
           'Branch' : 'Computer Science'} # creating the list

# %%
details['location'] = 'Jaipur' #add a new key and value

# %%
details['Branch']
# Out:
# 'Computer Science'

# %%
key, value = ('Name', 'Vinay Sharma')
print(key)
print(value)
# Out:
# Name
# Vinay Sharma

# %%
for any in details:
    print(details[any])
# Out:
# Vinay
# 25
# Computer Science
# Jaipur

# %%
for key in details.keys():
    print(f"{key} -> {details[key]}")
# Out:
# Name -> Vinay
# Age -> 25
# Branch -> Computer Science
# location -> Jaipur

# %%
# print the key which has the highest value
dic = {'a':3,'b':1,'c':5}
largest = 0
target=''
for key in dic:
    if dic[key]>largest:
        largest = dic[key]
        target = key

print(target)
# Out:
# c

# %%
d = {'a':3, 'b':1, 'c':5}
new = {}
for key,value in d.items():
    new[value] = key
print(new)
# Out:
# {3: 'a', 1: 'b', 5: 'c'}
