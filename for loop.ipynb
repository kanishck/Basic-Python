# %%
N = int(input("Enter N: "))

for i in range(1, N-1):
    print(i)

# %%
N = int(input("Enter N: "))

for i in range(N,0,-1):
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
N = int(input("Enter N: "))

for i in range(2, N+1, 2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
N = int(input("Enter N: "))
for i in range(1,N+1,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
N = int(input("Enter N: "))

for i in range(1,N+1):
    print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
N = int(input("Enter N: "))

for i in range(1,N+1):
    print(i*i*i)
# Out:
# 1
# 8
# 27
# 64
# 125

# %%
N = int(input("Enter N: "))

for i in range(N, 10*N+1, N):
    print(i)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
N = int(input("Enter N: "))

sum = 0

for i in range(1,N+1):
    sum += i

print(sum)
# Out:
# 15

# %%
N = int(input("Enter N: "))

sum = 0

for i in range(1,N+1):
    if i%2 ==0 :
        sum += i

print(sum)
# Out:
# 6

# %%
N = int(input("Enter N: "))

count = 0

for i in range(1,N+1):
    if i%2 ==0 :
        count += i

print(count)
# Out:
# 30

# %%
# 14. Find the sum of multiples of 3 from 1 to N.
N = int(input("Enter N : "))

sum = 0

for i in range(6, N+1):
    if i%3 == 0:
        sum += i
print(sum)
# Out:
# 15

# %%
# 16. Print all numbers divisible by a given number k.

N = int(input( "Enter N : "))
k = int(input("Enter k : "))

for i in range(k+1,N+1):
    if i%k == 0:
        print(i)
# Out:
# 8
# 12

# %%
# 17. Count numbers divisible by a given number k.

N = int(input( "Enter N : "))
k = int(input("Enter k : "))
count=0
for i in range(k+1,N+1):
    if i%k == 0:
        count += 1
        
print(count)
# Out:
# 2

# %%
# 19. Print numbers divisible by both 2 and 3.

N = int(input( "Enter N : "))

for i in range(6,N+1):
    if i%6 == 0 :
        print(i)
# Out:
# 6
# 12

# %%
# 20. Print numbers divisible by 3 but not by 5.

N = int(input("Enter N : "))

for i in range(5,N+1):
    if i%3==0 and i%5 !=0:
        print(i)
# Out:
# 6
# 9

# %%
N = int(input("Enter N: "))
k = int(input("Enter k: "))

for i in range(1, N + 1):
    if i % k == 0:
        print(i)

# %%
N = int(input("Enter N: "))
k = int(input("Enter k: "))

count = 0

for i in range(1, N + 1):
    if i % k == 0:
        count += 1

print(count)

# %%
N = int(input("Enter N: "))
k = int(input("Enter k: "))

total = 0

for i in range(1, N + 1):
    if i % k == 0:
        total += i

print(total)

# %%
# 51 Find the largest even number between 1 to N 

n = int(input("Enter the upper limit : "))
largest_even = 2

# %%
# 53. Find the first multiple of k greater than or equal to a given number.

k = int(input( "Enter the number : ") )

# %%
cum_sum =0
for i in range(1, 11):
    cum_sum += i
    print(cum_sum)

# %%
60. # Find the difference between the sum of even and odd numbers from 1 to N.

# %%
string = 'abcdefa'
stack = ''
for ch in string:
    if ch in stack:
        continue
    else:
        stack += ch
print(stack)
